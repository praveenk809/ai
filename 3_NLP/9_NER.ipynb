# %% [raw]
# # Named Entity Recognition
# Elon Musk, Barack Obama, Google, NASA, New York, India,"2024, March 30", $100, 50 euros

# %% [raw]
# PERSON (e.g Elon Musk, Barack Obama)
# GPE (Geopolitical entities e.g New York, India)
# Organizations (e.g. Google, NASA)
# DATE (e.g. 2024, March 30)
# Money (e.g $100, 50 euros)

# %%
import nltk
nltk.download("maxent_ne_chunker")
nltk.download("maxent_ne_chunker_tab")
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Ganesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Ganesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
sentence = "Barack Obama was born in Hawaii and served as President of the United States."
words = nltk.word_tokenize(sentence)
tag_elements = nltk.pos_tag(words)
tag_elements
# Out:
# [('Barack', 'NNP'),
#  ('Obama', 'NNP'),
#  ('was', 'VBD'),
#  ('born', 'VBN'),
#  ('in', 'IN'),
#  ('Hawaii', 'NNP'),
#  ('and', 'CC'),
#  ('served', 'VBD'),
#  ('as', 'IN'),
#  ('President', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('States', 'NNPS'),
#  ('.', '.')]

# %%
nltk.ne_chunk(tag_elements)
# Out:
# Tree('S', [Tree('PERSON', [('Barack', 'NNP')]), Tree('PERSON', [('Obama', 'NNP')]), ('was', 'VBD'), ('born', 'VBN'), ('in', 'IN'), Tree('GPE', [('Hawaii', 'NNP')]), ('and', 'CC'), ('served', 'VBD'), ('as', 'IN'), ('President', 'NNP'), ('of', 'IN'), ('the', 'DT'), Tree('GPE', [('United', 'NNP'), ('States', 'NNPS')]), ('.', '.')])

# %%
nltk.ne_chunk(tag_elements).draw()

# %% [raw]
# Gifts under 500rs
#
# SQL => price
#
# Select * from table where price<=500
