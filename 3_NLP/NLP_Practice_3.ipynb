# %%
# POS Tagging
# Lexical based Tagging

# %%
# Lexical Based tagging
# Rule based tagging
# Probability (Stochastic) techniques
# Model based tagging (ML, DL to train dataset and use it for predictions)

# %%
import nltk
from nltk import word_tokenize
from nltk import tag
import re
text = 'Today, I went to office, sorry, I forgot, today I was home and working remotly'

def postaging(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', "", text)
    text = word_tokenize(text)
    text = pos_tag(text)
    print(text)
postaging(text)
# Out:
# [('today', 'NN'), ('i', 'VB'), ('went', 'VBD'), ('to', 'TO'), ('office', 'NN'), ('sorry', 'NN'), ('i', 'VBP'), ('forgot', 'VBP'), ('today', 'NN'), ('i', 'NN'), ('was', 'VBD'), ('home', 'NN'), ('and', 'CC'), ('working', 'VBG'), ('remotly', 'RB')]
