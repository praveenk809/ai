# %% [raw]
# You are given two email messages, and the only information you were able to extract out of them, was the most commonly occuring words.
#
# Email 1 - the, hurry, !, lucky
#
# Email 2 - the, an, offer, sale
#
# Which one, according to you, is more likely to be a spam message?
#
# Ans: Email 1

# %%
"""There was nothing so _very_ remarkable in that; nor did Alice think it
so _very_ much out of the way to hear the Rabbit say to itself, “Oh
dear! Oh dear! I shall be late!” (when she thought it over afterwards,
it occurred to her that she ought to have wondered at this, but at the
time it all seemed quite natural);"""

# Word Frequencies
# Stop words: The, at, in , was, is , there...

# %%
import requests
url = "https://www.gutenberg.org/files/11/11-0.txt"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 response.text()
#
# NameError: name 'response' is not defined

# %%
pip install nltk

# %%
from nltk import FreqDist
words = response.text.split() # " "
word_freq = FreqDist(words)
word_freq
# Out:
# FreqDist({'the': 1515, 'and': 717, 'to': 706, 'a': 611, 'of': 493, 'she': 485, 'said': 416, 'it': 347, 'in': 346, 'was': 327, ...})

# %%
len(words)
# Out:
# 26543

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words("english")
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
len(stop_words)
# Out:
# 179

# %%
words = [word for word in words if word.lower() not in stop_words]
words

# %%
len(words)
# Out:
# 14729

# %%
word_freq = FreqDist(words)
word_freq
# Out:
# FreqDist({'said': 416, 'Alice': 221, '“I': 119, 'little': 118, 'went': 79, 'one': 77, 'Alice,': 76, 'like': 74, 'would': 68, 'thought': 63, ...})

# %%
word_freq.most_common(20)
# Out:
# [('said', 416),
#  ('Alice', 221),
#  ('“I', 119),
#  ('little', 118),
#  ('went', 79),
#  ('one', 77),
#  ('Alice,', 76),
#  ('like', 74),
#  ('would', 68),
#  ('thought', 63),
#  ('could', 63),
#  ('*', 60),
#  ('Mock', 57),
#  ('Alice.', 54),
#  ('quite', 53),
#  ('don’t', 48),
#  ('see', 47),
#  ('time', 46),
#  ('began', 46),
#  ('looked', 45)]

# %%
import seaborn as sns
def plot_word_frequency(words, top_n):
    word_freq = FreqDist(words)
    topn_words = word_freq.most_common(top_n)
    labels = [element[0] for element in topn_words]
    counts = [element[1] for element in topn_words]
    sns.barplot(x=labels, y=counts)
plot_word_frequency(words,10)
