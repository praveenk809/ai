# %% [raw]
# # Named Entity Recognition
# Elon Musk, Barack Obama, Google, New York, India, "2025, Mar 30", $100, 50 euros,

# %%
import nltk
nltk.download('maxent_ne_chunker')
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/praveengundamalla/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /Users/praveengundamalla/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
sentence = "Barack Obama was born in Hawaii and served as President of the United States."
words = nltk.word_tokenize(sentence)
tag_elements = nltk.pos_tag(words)
nltk.ne_chunk(tag_elements)
# Out:
# Tree('S', [Tree('PERSON', [('Barack', 'NNP')]), Tree('PERSON', [('Obama', 'NNP')]), ('was', 'VBD'), ('born', 'VBN'), ('in', 'IN'), Tree('GPE', [('Hawaii', 'NNP')]), ('and', 'CC'), ('served', 'VBD'), ('as', 'IN'), ('President', 'NNP'), ('of', 'IN'), ('the', 'DT'), Tree('GPE', [('United', 'NNP'), ('States', 'NNPS')]), ('.', '.')])

# %%
from ipynb.fs.full.NLP_Practice_3 import get_wordnet_pos

wordnet_elements = []

for word, pos in tag_elements:
    wordnet_pos = (word, get_wordnet_pos(pos))
    wordnet_elements.append(wordnet_pos)
wordnet_elements
# Out:
# n a v r
# [('Barack', 'n'),
#  ('Obama', 'n'),
#  ('was', 'v'),
#  ('born', 'v'),
#  ('in', 'n'),
#  ('Hawaii', 'n'),
#  ('and', 'n'),
#  ('served', 'v'),
#  ('as', 'n'),
#  ('President', 'n'),
#  ('of', 'n'),
#  ('the', 'n'),
#  ('United', 'n'),
#  ('States', 'n'),
#  ('.', 'n')]

# %%
import nltk
nltk.ne_chunk(wordnet_elements)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import nltk
# ----> 2 nltk.ne_chunk(wordnet_elements)
#
# NameError: name 'wordnet_elements' is not defined

# %%
#nltk.ne_chunk(wordnet_elements).draw()
